# %%
import os
import sys
sys.path.append(os.path.abspath("../tools"))

# %%
from dataset import SkysatLabelled
import torchvision
from config import Config_Resnet
# Out:
# c:\Users\esl26\AppData\Local\anaconda3\envs\harvest\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
transform = torchvision.transforms.Compose(
    [
        torchvision.transforms.ToPILImage(),
        torchvision.transforms.Resize((224, 224)),
        # torchvision.transforms.RandomHorizontalFlip(),
        # torchvision.transforms.RandomVerticalFlip(),
        torchvision.transforms.ToTensor(),
        # torchvision.transforms.Normalize(
        #     mean=[0.412, 0.368, 0.326], std=[0.110, 0.097, 0.098]
        # ),  # our dataset vals
    ]
)

# %%
config = Config_Resnet()

# %%
train_dataset = SkysatLabelled(
    os.path.join(config.dataset_path, "train.csv"),
    os.path.join(config.dataset_path, "skysat_images"),
    transform
)

# %%
print(train_dataset[1999][0])
# Out:
# tensor([[[0.3373, 0.4000, 0.4431,  ..., 0.4000, 0.4118, 0.4314],
#          [0.3569, 0.3882, 0.4314,  ..., 0.4039, 0.4196, 0.4314],
#          [0.3843, 0.3765, 0.4118,  ..., 0.4118, 0.4196, 0.4235],
#          ...,
#          [0.3961, 0.3804, 0.3804,  ..., 0.3569, 0.3765, 0.3843],
#          [0.4078, 0.3922, 0.4000,  ..., 0.3255, 0.3804, 0.4000],
#          [0.4118, 0.4078, 0.4039,  ..., 0.3569, 0.3843, 0.3922]],
#
#         [[0.3137, 0.3490, 0.3804,  ..., 0.3294, 0.3294, 0.3529],
#          [0.3216, 0.3412, 0.3686,  ..., 0.3373, 0.3451, 0.3569],
#          [0.3333, 0.3333, 0.3529,  ..., 0.3529, 0.3569, 0.3608],
#          ...,
#          [0.3373, 0.3294, 0.3294,  ..., 0.2980, 0.3137, 0.3176],
#          [0.3451, 0.3333, 0.3294,  ..., 0.2745, 0.3176, 0.3412],
#          [0.3490, 0.3412, 0.3294,  ..., 0.3020, 0.3255, 0.3294]],
#
#         [[0.2039, 0.2627, 0.2980,  ..., 0.2314, 0.2471, 0.2706],
#          [0.2314, 0.2471, 0.2941,  ..., 0.2510, 0.2627, 0.2706],
#          [0.2549, 0.2314, 0.2706,  ..., 0.2588, 0.2627, 0.2588],
#          ...,
#          [0.2706, 0.2588, 0.2627,  ..., 0.2118, 0.2353, 0.2549],
#          [0.2706, 0.2627, 0.2667,  ..., 0.1725, 0.2431, 0.2667],
#          [0.2667, 0.2667, 0.2667,  ..., 0.2157, 0.2510, 0.2471]]])

# %%
import matplotlib.pyplot as plt
plt.imshow(train_dataset[1999][0].permute(1,2,0))
