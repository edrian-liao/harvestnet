# %% [markdown]
# <a href="https://colab.research.google.com/github/edrian-liao/harvestnet/blob/main/notebooks/HarvestNet_Train_Model_Subdivisions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Required Packages

# %% [markdown]
# Conda was being funky with the python sys.executable, so decided to just import required packages using pip.

# %%
# !pip install wandb -qU
# !pip install torchmetrics -qU
# !pip install accelerate -qU
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.8/266.8 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.8 MB/s eta 0:00:00

# %%
import os
import time
import torch
from torch.utils.data import DataLoader
import torchvision
import wandb
import numpy as np
from torchmetrics import Accuracy, F1Score, AUROC, Precision, Recall
from accelerate import Accelerator
from collections import defaultdict
import cv2

# %%
from tools.dataset import SkysatLabelled
from tools.config import Config_Resnet

# %% [markdown]
# Login to wandb. might need to make an account.
# After creating account, you will get an API passkey, paste back into colab.

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Load Dataset

# %%
# -----------------
# CONFIG
# -----------------

config = Config_Resnet()


# Seed
torch.manual_seed(config.seed)
np.random.seed(config.seed)


accelerator = Accelerator(
    log_with="wandb",
    mixed_precision=config.mixed_precision,
)
device = accelerator.device

# Log on each process the small summary:
if accelerator.is_main_process:
    print(f"Training/evaluation parameters:")
    print(config.__dict__)

accelerator.init_trackers(
    config.wandb_project,
    config=config,
    init_kwargs={
        "wandb": {
            "group": config.wandb_group,
            "reinit": True,
            "dir": os.path.join(config.working_dir),
        }
    },
)

LOGGING = True
if LOGGING:
    accelerator.init_trackers(
        config.wandb_project,
        config=config,
        init_kwargs={
            "wandb": {
                "group": config.wandb_group,
                "reinit": True,
                "dir": os.path.join(config.working_dir),
            }
        },
    )


# -----------------
# DATASET
# -----------------
if accelerator.is_main_process:
    print("Loading datasets")
transform = torchvision.transforms.Compose(
    [
        torchvision.transforms.ToPILImage(),
        torchvision.transforms.Resize((224, 224)),
        # torchvision.transforms.RandomHorizontalFlip(),
        # torchvision.transforms.RandomVerticalFlip(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(
            mean=[0.412, 0.368, 0.326], std=[0.110, 0.097, 0.098]
        ),  # our dataset vals
    ]
)
# Out:
# wandb: Currently logged in as: edrianpaul-liao (ece661). Use `wandb login --relogin` to force relogin
# wandb: WARNING Path harvest-piles/wandb/ wasn't writable, using system temp directory.
# Training/evaluation parameters:
# {'working_dir': 'harvest-piles', 'dataset_path': 'dataset', 'wandb_project': 'harvest-piles', 'wandb_group': 'resnet50', 'seed': 2023, 'scheduler': 'one_cycle_lr', 'lr': 0.001, 'optimizer': 'madgrad', 'mixed_precision': 'fp16', 'num_train_epochs': 30, 'batch_size': 32}
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/tmp/wandb/run-20240425_191540-4hx6025n</code>
# Syncing run <strong><a href='https://wandb.ai/ece661/harvest-piles/runs/4hx6025n' target="_blank">kind-shadow-11</a></strong> to <a href='https://wandb.ai/ece661/harvest-piles' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ece661/harvest-piles' target="_blank">https://wandb.ai/ece661/harvest-piles</a>
#  View run at <a href='https://wandb.ai/ece661/harvest-piles/runs/4hx6025n' target="_blank">https://wandb.ai/ece661/harvest-piles/runs/4hx6025n</a>
# Finishing last run (ID:4hx6025n) before initializing another...
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">kind-shadow-11</strong> at: <a href='https://wandb.ai/ece661/harvest-piles/runs/4hx6025n' target="_blank">https://wandb.ai/ece661/harvest-piles/runs/4hx6025n</a><br/> View project at: <a href='https://wandb.ai/ece661/harvest-piles' target="_blank">https://wandb.ai/ece661/harvest-piles</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/tmp/wandb/run-20240425_191540-4hx6025n/logs</code>
# Successfully finished last run (ID:4hx6025n). Initializing new run:<br/>
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/tmp/wandb/run-20240425_191543-gnzazbk1</code>
# Syncing run <strong><a href='https://wandb.ai/ece661/harvest-piles/runs/gnzazbk1' target="_blank">silver-sun-12</a></strong> to <a href='https://wandb.ai/ece661/harvest-piles' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ece661/harvest-piles' target="_blank">https://wandb.ai/ece661/harvest-piles</a>
#  View run at <a href='https://wandb.ai/ece661/harvest-piles/runs/gnzazbk1' target="_blank">https://wandb.ai/ece661/harvest-piles/runs/gnzazbk1</a>
# Loading datasets

# %% [markdown]
# Mount google drive in order to load big skysat_images folder. Regular zipped upload did not work. Make sure you complete the following:
# 1. upload to your google drive a zipped version of skysat_images. make sure to name is skysat_images.zip
# 2. run the following code
# 3. after successfully unzipping skysat_images, make sure to move it to Dataset folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Academics/Spring 2024/ECE 661/Final Project/Patch_Dataset.zip" -d "/content/dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/50456_1.tif
#   inflating: /content/dataset/50456_2.tif
#   inflating: /content/dataset/50456_3.tif
#   inflating: /content/dataset/50456_4.tif
#   inflating: /content/dataset/5048_1.tif
#   inflating: /content/dataset/5048_2.tif
#   inflating: /content/dataset/5048_3.tif
#   inflating: /content/dataset/5048_4.tif
#   inflating: /content/dataset/50497_1.tif
#   inflating: /content/dataset/50497_2.tif
#   inflating: /content/dataset/50497_3.tif
#   inflating: /content/dataset/50497_4.tif
#   inflating: /content/dataset/50498_1.tif
#   inflating: /content/dataset/50498_2.tif
#   inflating: /content/dataset/50498_3.tif
#   inflating: /content/dataset/50498_4.tif
#   inflating: /content/dataset/505_1.tif
#   inflating: /content/dataset/505_2.tif
#   inflating: /content/dataset/505_3.tif
#   inflating: /content/dataset/505_4.tif
#   inflating: /content/dataset/50542_1.tif
#   inflating: /content/dataset/50542_2.tif
#   inflating: /content/dataset/50542_3.tif
#   inflating: /content/dataset/50542_4.tif
#   inflating: /content/dataset/50572_1.tif
#   inflating: /content/dataset/50572_2.tif
#   inflating: /content/dataset/50572_3.tif
#   inflating: /content/dataset/50572_4.tif
#   inflating: /content/dataset/50626_1.tif
#   inflating: /content/dataset/50626_2.tif
#   inflating: /content/dataset/50626_3.tif
#   inflating: /content/dataset/50626_4.tif
#   inflating: /content/dataset/5063_1.tif
#   inflating: /content/dataset/9987_4.tif
#   inflating: /content/dataset/9989_1.tif
#   inflating: /content/dataset/9989_2.tif
#   inflating: /content/dataset/9989_3.tif
#   inflating: /content/dataset/9989_4.tif
#   inflating: /content/dataset/999_1.tif
#   inflating: /content/dataset/999_2.tif
#   inflating: /content/dataset/999_3.tif
#   inflating: /content/dataset/999_4.tif
#   inflating: /content/dataset/9990_1.tif
#   inflating: /content/dataset/9990_2.tif
#   inflating: /content/dataset/9990_3.tif
#   inflating: /content/dataset/9990_4.tif
#   inflating: /content/dataset/9991_1.tif
#   inflating: /content/dataset/9991_2.tif
#   inflating: /content/dataset/9991_3.tif
#   inflating: /content/dataset/9991_4.tif
#   inflating: /content/dataset/9992_1.tif
#   inflating: /content/dataset/9992_2.tif
#   inflating: /content/dataset/9992_3.tif
#   inflating: /content/dataset/9992_4.tif
#   inflating: /content/dataset/9993_1.tif
#   inflating: /content/dataset/9993_2.tif
#   inflating: /content/dataset/9993_3.tif
#   inflating: /content/dataset/9993_4.tif
#   inflating: /content/dataset/9994_1.tif
#   inflating: /content/dataset/9994_2.tif
#   inflating: /content/dataset/9994_3.tif
#   inflating: /content/dataset/9994_4.tif
#   inflating: /content/dataset/9995_1.tif
#   inflating: /content/dataset/9995_2.tif
#   inflating: /content/dataset/9995_3.tif
#   inflating: /content/dataset/9995_4.tif
#   inflating: /content/dataset/9996_1.tif
#   inflating: /content/dataset/9996_2.tif
#   inflating: /content/dataset/9996_3.tif
#   inflating: /content/dataset/9996_4.tif
#   inflating: /content/dataset/9997_1.tif
#   inflating: /content/dataset/9997_2.tif
#   inflating: /content/dataset/9997_3.tif
#   inflating: /content/dataset/9997_4.tif
#   inflating: /content/dataset/9998_1.tif
#   inflating: /content/dataset/9998_2.tif
#   inflating: /content/dataset/9998_3.tif
#   inflating: /content/dataset/9998_4.tif
#   inflating: /content/dataset/9999_1.tif
#   inflating: /content/dataset/9999_2.tif
#   inflating: /content/dataset/9999_3.tif
#   inflating: /content/dataset/9999_4.tif

# %% [markdown]
# NOTE: Move the unzipped sky_sat images into Dataset folder before continuing

# %% [markdown]
# # Preprocess CSVs to Remove Broken Images

# %% [markdown]
# Train Dataset

# %%
import pandas as pd
import os

IMAGE_DIR = "dataset"
TRAIN_FILE = "dataset/train_subdivided.csv"
TEST_FILE = "dataset/test_subdivided.csv"

df = pd.read_csv(TRAIN_FILE, usecols=["filename"])
df.reset_index(inplace=True, drop=True)
examples = df["filename"]
print(examples)
# Out:
# 0          746_1.tif
# 1          746_2.tif
# 2          746_3.tif
# 3          746_4.tif
# 4         6025_1.tif
#             ...
# 22123    17192_4.tif
# 22124    12217_1.tif
# 22125    12217_2.tif
# 22126    12217_3.tif
# 22127    12217_4.tif
# Name: filename, Length: 22128, dtype: object

# %%
# Get broken images
broken_images = []
for index in range(len(examples)):
    try:
        path = os.path.join(IMAGE_DIR, examples[index])
        image = cv2.imread(path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    except:
        print(examples[index])
        broken_images.append(examples[index])
# Out:
# 6014_1.tif
# 6014_2.tif
# 6014_3.tif
# 6014_4.tif

# %%
print(len(broken_images))
# Out:
# 4

# %% [markdown]
# Remove Them

# %%
# get the original train and test csv
train = pd.read_csv(TRAIN_FILE)
train = train.iloc[:, 1:]

test = pd.read_csv(TEST_FILE)
test = test.iloc[:, 1:]

print(train.shape)
print(test.shape)
# Out:
# (22128, 13)
# (5532, 13)

# %%
# filter the broken images from train and test csv
train_filtered = train[~train['filename'].isin(broken_images)]
train_filtered.reset_index(inplace=True)

test_filtered = test[~test['filename'].isin(broken_images)]
test_filtered.reset_index(inplace=True)

print(train_filtered.shape)
print(test_filtered.shape)
# Out:
# (22124, 14)
# (5532, 14)

# %%
for index, row in train_filtered.iterrows():
    if int(row["filename"][:-4]) != index:
        print (index)
        break

for index, row in test_filtered.iterrows():
    if int(row["filename"][:-4]) != index:
        print (index)
        break



# drop level_0 and index columns
train_filtered.drop(["index"], axis=1, inplace=True)
test_filtered.drop(["index"], axis=1, inplace=True)

print(train_filtered.shape)
print(test_filtered.shape)
# Out:
# 0
# 0
# (22124, 13)
# (5532, 13)
# <ipython-input-15-9c515a829f93>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_filtered.drop(["index"], axis=1, inplace=True)

# %%
# replace the train and test csvs with the filtered versions
train_filtered.to_csv("dataset/train_subdivided.csv")
test_filtered.to_csv("dataset/test_subdivided.csv")

# %%
# LOAD DATASETS
ROOT_PATH = "Dataset"
train_dataset = SkysatLabelled(
    os.path.join(config.dataset_path, "train_subdivided.csv"),
    os.path.join(config.dataset_path, ""),
    transform,
)

test_dataset = SkysatLabelled(
    os.path.join(config.dataset_path, "test_subdivided.csv"),
    os.path.join(config.dataset_path, ""),
    transform,
)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
)

# %% [markdown]
# Check the content of both datasets to confirm we are looking at the correct data.

# %%
# check how many images are in train_dataset
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 22124
# 5532

# %%
import matplotlib.pyplot as plt
plt.imshow(train_dataset[1999][0].permute(1,2,0))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Train Dataset

# %% [markdown]
# At this point, hopefully the model can be trained.

# %%
# -----------------
# MODEL
# -----------------
if accelerator.is_main_process:
    print("Loading model")

model_weights = torchvision.models.ResNet50_Weights.IMAGENET1K_V2


class ResNet50(torch.nn.Module):
    def __init__(self, num_classes):
        super(ResNet50, self).__init__()
        self.resnet50 = torchvision.models.resnet50(weights=model_weights)
        num_features = self.resnet50.fc.out_features
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(num_features, num_classes),
            torch.nn.Sigmoid(),
        )

    def forward(self, x):
        logits = self.resnet50(x)
        return self.fc(logits)


out_classes = 1
model = ResNet50(out_classes)

# -----------------
# OPTIMIZER, SCHEDULER
# -----------------
criterion = torch.nn.BCELoss()

accuracy = Accuracy(task="binary")
f1_score = F1Score(task="binary")
auroc = AUROC(task="binary")
precision = Precision(task="binary")
recall = Recall(task="binary")

FOUND_LR = config.lr  # For OneCycleLR
# FOUND_LR = 0.001 # For ExponentialLR


params = [
    {"params": model.resnet50.conv1.parameters(), "lr": FOUND_LR / 10},
    {"params": model.resnet50.bn1.parameters(), "lr": FOUND_LR / 10},
    {"params": model.resnet50.layer1.parameters(), "lr": FOUND_LR / 8},
    {"params": model.resnet50.layer2.parameters(), "lr": FOUND_LR / 6},
    {"params": model.resnet50.layer3.parameters(), "lr": FOUND_LR / 4},
    {"params": model.resnet50.layer4.parameters(), "lr": FOUND_LR / 2},
    {"params": model.resnet50.fc.parameters()},
]
if config.optimizer == "adam":
    optimizer = torch.optim.Adam(params, lr=config.lr)
elif config.optimizer == "madgrad":
    from tools.madgrad import MADGRAD

    optimizer = MADGRAD(params, lr=config.lr)

STEPS_PER_EPOCH = len(train_dataloader)
TOTAL_STEPS = config.num_train_epochs * STEPS_PER_EPOCH
MAX_LRS = [p["lr"] for p in optimizer.param_groups]

if config.scheduler == "one_cycle_lr":
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer, max_lr=MAX_LRS, total_steps=TOTAL_STEPS
    )

# -----------------
# ACCELERATOR
# -----------------
model, optimizer, train_dataloader, test_dataloader, scheduler = accelerator.prepare(
    model, optimizer, train_dataloader, test_dataloader, scheduler
)
accuracy, f1_score, auroc, precision, recall = accelerator.prepare(
    accuracy, f1_score, auroc, precision, recall
)

# -----------------
# TRAIN
# -----------------
if accelerator.is_main_process:
    print("Begin train")


def train(model, iterator, optimizer, criterion, scheduler):
    epoch_loss = 0
    sum_metrics = defaultdict(float)

    model.train()
    for x, y, _ in iterator:
        optimizer.zero_grad()

        pred = model(x)
        loss = criterion(pred, y)
        evals = {
            "acc": accuracy(pred, y),
            "f1": f1_score(pred, y),
            "auroc": auroc(pred, y),
            "precision": precision(pred, y),
            "recall": recall(pred, y),
        }
        for k, v in evals.items():
            sum_metrics[k] += v

        accelerator.backward(loss)
        optimizer.step()
        if config.scheduler == "one_cycle_lr":
            scheduler.step()

        epoch_loss += loss.item()

    if config.scheduler != "one_cycle_lr":
        scheduler.step()

    epoch_loss /= len(iterator)
    avg_metrics = {k: v / len(iterator) for k, v in sum_metrics.items()}
    print(avg_metrics)

    return epoch_loss, avg_metrics


def evaluate(model, iterator, criterion):
    epoch_loss = 0
    sum_metrics = defaultdict(float)

    model.eval()

    with torch.no_grad():
        for x, y, _ in iterator:
            pred = model(x)
            loss = criterion(pred, y)
            evals = {
                "acc": accuracy(pred, y),
                "f1": f1_score(pred, y),
                "auroc": auroc(pred, y),
                "precision": precision(pred, y),
                "recall": recall(pred, y),
            }
            for k, v in evals.items():
                sum_metrics[k] += v

            epoch_loss += loss.item()

    epoch_loss /= len(iterator)
    avg_metrics = {k: v / len(iterator) for k, v in sum_metrics.items()}
    print(avg_metrics)

    return epoch_loss, avg_metrics


def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs


best_val = 0

if LOGGING:
    print("Batch size:", config.batch_size)
    print("Batches per epoch:", len(train_dataloader))
for epoch in range(config.num_train_epochs):
    start_time = time.time()

    train_loss, train_metrics = train(
        model, train_dataloader, optimizer, criterion, scheduler
    )
    valid_loss, val_metrics = evaluate(model, test_dataloader, criterion)
    if LOGGING:
        wandb.log({"train.loss": train_loss}, commit=False)
        wandb.log({"train": train_metrics}, commit=False)
        wandb.log({"val.loss": valid_loss}, commit=False)
        wandb.log({"val": val_metrics}, commit=False)

    if val_metrics["acc"] > best_val:
        best_val = val_metrics["acc"]
        unwrapped_model = accelerator.unwrap_model(model)
        torch.save(
            model.state_dict(), "Results/best_resnet_subdivided.pt"
        )

    end_time = time.time()
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    if accelerator.is_main_process:
        print(f"Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s")
        print(
            f"\tTrain Loss: {train_loss:.3f} | Train Acc: {train_metrics['acc'] * 100:6.2f}%"
        )
        print(
            f"\tValid Loss: {valid_loss:.3f} | Valid Acc: {val_metrics['acc'] * 100:6.2f}%"
        )

    if LOGGING:
        wandb.log({"epoch": epoch}, commit=True)
# Out:
# Loading model
# Begin train
# Batch size: 32
# Batches per epoch: 692
# {'acc': tensor(0.7080, device='cuda:0'), 'f1': tensor(0.6568, device='cuda:0'), 'auroc': tensor(0.7865, device='cuda:0'), 'precision': tensor(0.7142, device='cuda:0'), 'recall': tensor(0.6297, device='cuda:0')}
# {'acc': tensor(0.7218, device='cuda:0'), 'f1': tensor(0.5957, device='cuda:0'), 'auroc': tensor(0.8045, device='cuda:0'), 'precision': tensor(0.7882, device='cuda:0'), 'recall': tensor(0.4941, device='cuda:0')}
# Epoch: 01 | Epoch Time: 6m 33s
# 	Train Loss: 0.550 | Train Acc:  70.80%
# 	Valid Loss: 0.540 | Valid Acc:  72.18%
# {'acc': tensor(0.7669, device='cuda:0'), 'f1': tensor(0.7298, device='cuda:0'), 'auroc': tensor(0.8528, device='cuda:0'), 'precision': tensor(0.7778, device='cuda:0'), 'recall': tensor(0.7041, device='cuda:0')}
# {'acc': tensor(0.7428, device='cuda:0'), 'f1': tensor(0.6732, device='cuda:0'), 'auroc': tensor(0.8224, device='cuda:0'), 'precision': tensor(0.7295, device='cuda:0'), 'recall': tensor(0.6391, device='cuda:0')}
# Epoch: 02 | Epoch Time: 6m 49s
# 	Train Loss: 0.483 | Train Acc:  76.69%
# 	Valid Loss: 0.532 | Valid Acc:  74.28%
# {'acc': tensor(0.7851, device='cuda:0'), 'f1': tensor(0.7510, device='cuda:0'), 'auroc': tensor(0.8748, device='cuda:0'), 'precision': tensor(0.7958, device='cuda:0'), 'recall': tensor(0.7288, device='cuda:0')}
# {'acc': tensor(0.6929, device='cuda:0'), 'f1': tensor(0.5363, device='cuda:0'), 'auroc': tensor(0.7727, device='cuda:0'), 'precision': tensor(0.7644, device='cuda:0'), 'recall': tensor(0.4255, device='cuda:0')}
# {'acc': tensor(0.7226, device='cuda:0'), 'f1': tensor(0.6863, device='cuda:0'), 'auroc': tensor(0.7987, device='cuda:0'), 'precision': tensor(0.6695, device='cuda:0'), 'recall': tensor(0.7207, device='cuda:0')}
# Epoch: 08 | Epoch Time: 6m 14s
# 	Train Loss: 0.376 | Train Acc:  83.17%
# 	Valid Loss: 0.638 | Valid Acc:  72.26%
# {'acc': tensor(0.8552, device='cuda:0'), 'f1': tensor(0.8340, device='cuda:0'), 'auroc': tensor(0.9367, device='cuda:0'), 'precision': tensor(0.8601, device='cuda:0'), 'recall': tensor(0.8236, device='cuda:0')}
# {'acc': tensor(0.7117, device='cuda:0'), 'f1': tensor(0.6723, device='cuda:0'), 'auroc': tensor(0.7838, device='cuda:0'), 'precision': tensor(0.6584, device='cuda:0'), 'recall': tensor(0.7021, device='cuda:0')}
# Epoch: 09 | Epoch Time: 6m 15s
# 	Train Loss: 0.336 | Train Acc:  85.52%
# 	Valid Loss: 0.695 | Valid Acc:  71.17%
# {'acc': tensor(0.8780, device='cuda:0'), 'f1': tensor(0.8622, device='cuda:0'), 'auroc': tensor(0.9542, device='cuda:0'), 'precision': tensor(0.8820, device='cuda:0'), 'recall': tensor(0.8550, device='cuda:0')}
# {'acc': tensor(0.7190, device='cuda:0'), 'f1': tensor(0.6697, device='cuda:0'), 'auroc': tensor(0.8012, device='cuda:0'), 'precision': tensor(0.6789, device='cuda:0'), 'recall': tensor(0.6761, device='cuda:0')}
# Epoch: 10 | Epoch Time: 6m 14s
# 	Train Loss: 0.286 | Train Acc:  87.80%
# 	Valid Loss: 0.746 | Valid Acc:  71.90%
# {'acc': tensor(0.8994, device='cuda:0'), 'f1': tensor(0.8862, device='cuda:0'), 'auroc': tensor(0.9670, device='cuda:0'), 'precision': tensor(0.9034, device='cuda:0'), 'recall': tensor(0.8793, device='cuda:0')}
# {'acc': tensor(0.6374, device='cuda:0'), 'f1': tensor(0.6645, device='cuda:0'), 'auroc': tensor(0.7736, device='cuda:0'), 'precision': tensor(0.5530, device='cuda:0'), 'recall': tensor(0.8536, device='cuda:0')}
# Epoch: 11 | Epoch Time: 6m 13s
# 	Train Loss: 0.242 | Train Acc:  89.94%
# 	Valid Loss: 1.748 | Valid Acc:  63.74%
# {'acc': tensor(0.9265, device='cuda:0'), 'f1': tensor(0.9174, device='cuda:0'), 'auroc': tensor(0.9809, device='cuda:0'), 'precision': tensor(0.9291, device='cuda:0'), 'recall': tensor(0.9125, device='cuda:0')}
# {'acc': tensor(0.7007, device='cuda:0'), 'f1': tensor(0.6636, device='cuda:0'), 'auroc': tensor(0.7840, device='cuda:0'), 'precision': tensor(0.6446, device='cuda:0'), 'recall': tensor(0.7000, device='cuda:0')}
# Epoch: 12 | Epoch Time: 6m 15s
# 	Train Loss: 0.191 | Train Acc:  92.65%
# 	Valid Loss: 1.241 | Valid Acc:  70.07%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-de6db62cff02> in <cell line: 163>()
#     164     start_time = time.time()
#     165
# --> 166     train_loss, train_metrics = train(
#     167         model, train_dataloader, optimizer, criterion, scheduler
#     168     )
#
# <ipython-input-23-de6db62cff02> in train(model, iterator, optimizer, criterion, scheduler)
#      98             "auroc": auroc(pred, y),
#      99             "precision": precision(pred, y),
# --> 100             "recall": recall(pred, y),
#     101         }
#     102         for k, v in evals.items():
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     823
#     824     def forward(*args, **kwargs):
# --> 825         return model_forward(*args, **kwargs)
#     826
#     827     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     811
#     812     def __call__(self, *args, **kwargs):
# --> 813         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     814
#     815     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      14     def decorate_autocast(*args, **kwargs):
#      15         with autocast_instance:
# ---> 16             return func(*args, **kwargs)
#      17
#      18     decorate_autocast.__script_unsupported = "@autocast() decorator is not supported in script mode"  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/metric.py in forward(self, *args, **kwargs)
#     302             self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     303         else:
# --> 304             self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     305
#     306         return self._forward_cache
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/metric.py in _forward_reduce_state_update(self, *args, **kwargs)
#     371
#     372         # calculate batch state and compute batch value
# --> 373         self.update(*args, **kwargs)
#     374         batch_val = self.compute()
#     375
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/metric.py in wrapped_func(*args, **kwargs)
#     464             with torch.set_grad_enabled(self._enable_grad):
#     465                 try:
# --> 466                     update(*args, **kwargs)
#     467                 except RuntimeError as err:
#     468                     if "Expected all tensors to be on" in str(err):
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/classification/stat_scores.py in update(self, preds, target)
#     185             _binary_stat_scores_tensor_validation(preds, target, self.multidim_average, self.ignore_index)
#     186         preds, target = _binary_stat_scores_format(preds, target, self.threshold, self.ignore_index)
# --> 187         tp, fp, tn, fn = _binary_stat_scores_update(preds, target, self.multidim_average)
#     188         self._update_state(tp, fp, tn, fn)
#     189
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/functional/classification/stat_scores.py in _binary_stat_scores_update(preds, target, multidim_average)
#     125     """Compute the statistics."""
#     126     sum_dim = [0, 1] if multidim_average == "global" else [1]
# --> 127     tp = ((target == preds) & (target == 1)).sum(sum_dim).squeeze()
#     128     fn = ((target != preds) & (target == 1)).sum(sum_dim).squeeze()
#     129     fp = ((target != preds) & (target == 0)).sum(sum_dim).squeeze()
#
# KeyboardInterrupt:

# %%
# check best val
print(best_val)
# Out:
# tensor(0.7428, device='cuda:0')
